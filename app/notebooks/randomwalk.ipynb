# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T = 100
sigma = 1.0
eps = np.random.normal(0, sigma, size=T)
X = np.cumsum(eps)  # X0=0 からの累積和

plt.plot(X)
plt.title("Random Walk Simulation")
plt.xlabel("Time")
plt.ylabel("X_t")
plt.show()
